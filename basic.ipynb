# %%
1+1
# Out:
# 2

# %%
a= 10

# %%
type(a)
# Out:
# int

# %%
n= True

# %%
type(n)
# Out:
# bool

# %%
m=False

# %%
m+n
# Out:
# 1

# %%
v=5+8j

# %%
type(v)
# Out:
# complex

# %%
v.real
# Out:
# 5.0

# %%
v.imag
# Out:
# 8.0

# %%
print(a)
# Out:
# 10

# %%
print(v)
# Out:
# (5+8j)

# %%
s="pwskills"

# %%
s[0]
# Out:
# 'p'

# %%
s[3]
# Out:
# 'k'

# %%
s[6]
# Out:
# 'l'

# %%
s[-2]
# Out:
# 'l'

# %%
s[0:3]   #sliceing- data provide (uppwebound -1)
# Out:
# 'pws'

# %%
s[0:8:2]
# Out:
# 'psil'

# %%
s[::2]
# Out:
# 'psil'

# %%
s[2::1]
# Out:
# 'skills'

# %%
s[::-1]
# Out:
# 'sllikswp'

# %%
s[2:7:-1]
# Out:
# ''

# %%
s[8:0]
# Out:
# ''

# %%
s[8:0:-1]
# Out:
# 'slliksw'

# %%
s[-2:-8:1]
# Out:
# ''

# %%
s[-2:-8:-1]
# Out:
# 'lliksw'

# %%
s[::-1]
# Out:
# 'sllikswp'

# %%
s[::]
# Out:
# 'pwskills'

# %%
s[:-90:-1]
# Out:
# 'sllikswp'

# %%
c='200'

# %%
c[1]
# Out:
# '0'

# %%
s1= "this is string class"

# %%
len(s1)
# Out:
# 20

# %%
s1.find('s')
# Out:
# 3

# %%
s1.find('is')
# Out:
# 2

# %%
s1.find('iS')
# Out:
# -1

# %%
s1.count('s')
# Out:
# 5

# %%
s1.count('z')
# Out:
# 0

# %%
s1.upper()
# Out:
# 'THIS IS STRING CLASS'

# %%
s1.lower()
# Out:
# 'this is string class'

# %%
s1.title()
# Out:
# 'This Is String Class'

# %%
s1.capitalize()
# Out:
# 'This is string class'

# %%
s
# Out:
# 'pwskills'

# %%
s+ s
# Out:
# 'pwskillspwskills'

# %%
s
# Out:
# 'pwskills'

# %%
s*3
# Out:
# 'pwskillspwskillspwskills'

# %%
s+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[348], line 1
# ----> 1 s+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
"don't do copy and pest in class"
# Out:
# "don't do copy and pest in class"

# %%
'don't do copy and pest in class'
# Out:
#   Cell In[350], line 1
#     'don't do copy and pest in class'
#                                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
#this is my first class for programming  this is comment
